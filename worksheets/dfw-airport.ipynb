# %% [markdown]
# All features here are delays and are categorized by subtypes.
#
# ## Create a Barplot

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

airline_df = pd.read_csv("../data/dfw_airline.csv")

plt.bar(airline_df.columns, airline_df.values[0])
# Out:
# <BarContainer object of 5 artists>
